# %% [markdown]
# ### Task-1: Product Collections (Lists & Tuples)

# %% [markdown]
# 1. Create a list named products cintaining at least 6 product names(strings).

# %%
product_list = ["Oil", "Diaper", "Fruits", "Handwash", "Snacks", "Soap"]

# %%
type(product_list)
# Out:
# list

# %% [markdown]
# 2. Create tuple named sample_product that stores (product_name,price,category) for one product.

# %%
sample_product = ("Dove", 30 , "Soap")

# %%
type(sample_product)
# Out:
# tuple

# %% [markdown]
# 3. Print the 2nd and last product from the products list.

# %%
print(product_list[1],product_list[-1])
# Out:
# Diaper Soap

# %% [markdown]
# 4. Append two new product names to products and then print the updated list.

# %%
product_list.append("Shampoo")
product_list.append("Bodywash")
print(product_list)
# Out:
# ['Oil', 'Diaper', 'Fruits', 'Handwash', 'Snacks', 'Shampoo', 'Bodywash']

# %% [markdown]
# Optional: Convert sample_product into a list, change its price, and convert it back to a tuple.

# %%
sample_lst = list(sample_product) #converting tuple into list
sample_lst[1] = 40 #changing price value
sample_product = tuple(sample_lst)
print(sample_product)
# Out:
# ('Dove', 40, 'Soap')
